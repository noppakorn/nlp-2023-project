# %%
# %env WANDB_PROJECT=bart-summarizer
# Out:
# env: WANDB_PROJECT=bart-summarizer

# %%
# !pip install transformers datasets evaluate rouge_score wandb ipywidgets==7.7.1 huggingface_hub

# %% [markdown]
# ## Dataset

# %%
# !curl -LO https://gist.github.com/noppakorn/627605aa61afa4a8f080f9996d0b10dd/raw/66489226825261ceb08aa02f064c15b45dc6a887/rate-my-prof-raw-dataset.csv
# !curl -LO https://gist.githubusercontent.com/noppakorn/8d4a7be866d18cd7dec5ada7aa8d8d0d/raw/f1114e613f302de830500cf4dd2701d661c7eba4/summarized_dataset.csv

# %% [markdown]
# ## Logger Login

# %%
# !wandb login

# %%
# from huggingface_hub import notebook_login

# notebook_login()

# %% [markdown]
# ## Import and Seeds

# %%
seed = 42 # The answer to everything

import torch
torch.manual_seed(seed)
torch.use_deterministic_algorithms(True)

import random
random.seed(seed)

import numpy as np
np.random.seed(seed)


def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

g = torch.Generator()
g.manual_seed(seed)

import transformers
transformers.enable_full_determinism(seed)

# %%
import re
import pandas as pd

import torchtext

from transformers import AutoTokenizer, DataCollatorForSeq2Seq
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer

from datasets import load_dataset

import evaluate

# %% [markdown]
# ## Prepare the data

# %%
checkpoint = "sshleifer/distilbart-cnn-12-6"
# checkpoint = "facebook/bart-large-cnn"

# %%
tokenizer = AutoTokenizer.from_pretrained(checkpoint)

# %%
def preprocess_function(data):
    inputs = [doc for doc in data["text"]]
    model_inputs = tokenizer(inputs, max_length=1024, truncation=True)
    labels = tokenizer(text_target=data["summary"], max_length=70, truncation=True)
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
data = load_dataset("csv", data_files="summarized_dataset.csv")
data = data["train"].train_test_split(test_size=0.1)
# Out:
# Downloading and preparing dataset csv/default to /root/.cache/huggingface/datasets/csv/default-99c532b369dc8738/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1...
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Dataset csv downloaded and prepared to /root/.cache/huggingface/datasets/csv/default-99c532b369dc8738/0.0.0/6954658bab30a358235fa864b05cf819af0e179325c740e4bc853bcc7ec513e1. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
tokenized_data = data.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/270 [00:00<?, ? examples/s]
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]

# %%
data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=checkpoint)

rouge = evaluate.load("rouge")
# Out:
# Downloading builder script:   0%|          | 0.00/6.27k [00:00<?, ?B/s]

# %% [markdown]
# ## Training

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    result = rouge.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}

# %%
model = AutoModelForSeq2SeqLM.from_pretrained(checkpoint)
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="distilbart-cnn-12-6-rate-prof",
    evaluation_strategy="epoch",
    learning_rate=1e-5,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    weight_decay=0.01,
    save_total_limit=4,
    num_train_epochs=5,
    predict_with_generate=True,
    fp16=True,
    push_to_hub=True,
    report_to="wandb",
)

# %%
trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_data["train"],
    eval_dataset=tokenized_data["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# Cloning https://huggingface.co/noppakornj/distilbart-cnn-12-6-rate-prof into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/noppakornj/distilbart-cnn-12-6-rate-prof into local empty directory.

# %%
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# wandb: Currently logged in as: noppakorn (meen). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.0
# Run data is saved locally in <code>/content/wandb/run-20230430_133435-a0vsd7sj</code>
# Syncing run <strong><a href='https://wandb.ai/meen/bart-summarizer/runs/a0vsd7sj' target="_blank">stilted-sponge-10</a></strong> to <a href='https://wandb.ai/meen/bart-summarizer' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/meen/bart-summarizer' target="_blank">https://wandb.ai/meen/bart-summarizer</a>
#  View run at <a href='https://wandb.ai/meen/bart-summarizer/runs/a0vsd7sj' target="_blank">https://wandb.ai/meen/bart-summarizer/runs/a0vsd7sj</a>
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='340' max='340' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [340/340 07:35, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>1.153038</td>
#       <td>0.284400</td>
#       <td>0.094300</td>
#       <td>0.204000</td>
#       <td>0.202700</td>
#       <td>67.800000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>1.094786</td>
#       <td>0.261400</td>
#       <td>0.049800</td>
#       <td>0.167200</td>
#       <td>0.168000</td>
#       <td>67.800000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>1.079701</td>
#       <td>0.304200</td>
#       <td>0.098300</td>
#       <td>0.206800</td>
#       <td>0.208200</td>
#       <td>66.666700</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>1.080752</td>
#       <td>0.293200</td>
#       <td>0.091400</td>
#       <td>0.201200</td>
#       <td>0.202400</td>
#       <td>67.133300</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>1.092212</td>
#       <td>0.304100</td>
#       <td>0.119600</td>
#       <td>0.222900</td>
#       <td>0.224100</td>
#       <td>66.933300</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=340, training_loss=0.7534892362706801, metrics={'train_runtime': 464.4899, 'train_samples_per_second': 2.906, 'train_steps_per_second': 0.732, 'total_flos': 2088453869518848.0, 'train_loss': 0.7534892362706801, 'epoch': 5.0})

# %%
trainer.push_to_hub() # Save result to hugging face hub
# Out:
# Upload file pytorch_model.bin:   0%|          | 1.00/1.14G [00:00<?, ?B/s]
# Upload file training_args.bin:   0%|          | 1.00/3.68k [00:00<?, ?B/s]
# To https://huggingface.co/noppakornj/distilbart-cnn-12-6-rate-prof
#    e517f5c..979ed83  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/noppakornj/distilbart-cnn-12-6-rate-prof
#    e517f5c..979ed83  main -> main
#
# To https://huggingface.co/noppakornj/distilbart-cnn-12-6-rate-prof
#    979ed83..6371c71  main -> main
#
# WARNING:huggingface_hub.repository:To https://huggingface.co/noppakornj/distilbart-cnn-12-6-rate-prof
#    979ed83..6371c71  main -> main
# 'https://huggingface.co/noppakornj/distilbart-cnn-12-6-rate-prof/commit/979ed831c715f93ef73ef003adc8b9ca57766787'

# %% [markdown]
# ## Predictions

# %%
pred_result = trainer.predict(test_dataset=tokenized_data["test"])

# %%
pred_decode = tokenizer.batch_decode(pred_result[0], skip_special_tokens=True)

# %%
idx = 7

print("Professor id", data["test"]["id"][idx])

print("Target: ", data["test"]["summary"][idx])
print()
print("Generated: ", pred_decode[idx])
# Out:
# Professor id 636
# Target:  He can be hard to understand at some points, but he seems to know what he is talking about and is good at teaching the information. Sit close to the front as he is soft spoken. The lab assignments are easy. Projects are mostly incomprehensible.
#
# Generated:  VERY hard to understand. Easy class but I didn't learn a thing. Very difficult to undserstand over his heavy accent. Class is pretty difficult if you dont know computer lingo. It's basically like taking a language class and the professor doesnt help much.

# %%
pred_dict = [{"id": i, "target": j, "generated": k, } for i, j, k in zip(data["test"]["id"], data["test"]["summary"], pred_decode)]

pred_df = pd.DataFrame.from_dict(pred_dict)

rouge_pred = pred_df.apply(lambda x: rouge.compute(predictions=[x["generated"]], references=[x["target"]], use_stemmer=True), axis=1).apply(pd.Series)

pred_df = pred_df.join(rouge_pred)

# %%
pred_df
# Out:
#      id                                             target  \
# 0   593  She is such a great person and she has so much...
# 1   668  Dr. Karplus curves the class generously only b...
# 2   202  Great professor! A bit disorganized, but also ...
# 3   583  His lectures are aimless and unclear a lot of ...
# 4   413  By far my favorite professor at UD. Gives grea...
# 5   137  I was looking forward to this class and was gr...
# 6   332  Quite possibly the worst excuse for a teacher ...
# 7   636  He can be hard to understand at some points, b...
# 8   110  Dr. Smith is extremely knowledgeable and enthu...
# 9   586  Great Professor and an easy A. this class is s...
# 10  458  he has the ability to make the class outstandi...
# 11  664  He is an all around great guy. Grades papers p...
# 12  497  She is a great teacher. She make learn german ...
# 13  176  One of the worst professors I've ever had. Wou...
# 14  673  He's very chill and laid back, although his vo...
# 15  464  Very nice guy, tries to be funny  and on occas...
# 16  235  Makes labs way longer than they need to be bec...
# 17  184  Take this review to heart. He is horrible in t...
# 18  273  Prof. Peterman is by far the worst professor I...
# 19  446  Funny guy. Willing to help. Tests are challeng...
# 20  560  He requires attendance, doesn't use Canvas, an...
# 21  679  one of the hardest teachers I have ever had.  ...
# 22  549  Teachers were praised for being passionate abo...
# 23  611  She provides excellent lectures. she grades to...
# 24  604  goes over lots of things in class. Exams are l...
# 25  627  Avoid this professor at all costs. Lectures ar...
# 26    3  Pros:clear plans for the whole semester, cours...
# 27  210  LOVED this teacher. He is older so he has stor...
# 28  480  Criteria is pretty clear. she's not a bad teac...
# 29  259  Awful prof. Lecture content was outdated and q...
#
#                                             generated    rouge1    rouge2  \
# 0   Pat rocks! She's a really great teacher, very ...  0.252252  0.018349
# 1   Andy definitely cares about his students succe...  0.285714  0.038835
# 2   Great professor! A bit disorganized, but also ...  0.769231  0.764045
# 3   He seems like a really nice guy who is obvious...  0.297521  0.033613
# 4   Awesome dude, well-versed, and genuinely cares...  0.359551  0.183908
# 5   Worst professor I have ever had. Doesn't liste...  0.285714  0.017094
# 6   The man is the worst professor I have ever had...  0.307692  0.034783
# 7   VERY hard to understand. Easy class but I didn...  0.222222  0.045455
# 8   The best professor by far! He knows his stuff ...  0.299213  0.032000
# 9   Eugene was awesome. No textbook, no tests. Its...  0.198020  0.000000
# 10  Dr. Browning is extremely intelligent and know...  0.273684  0.043011
# 11  One of the most transformative classroom exper...  0.080808  0.000000
# 12  She is an amazing German professor and really ...  0.181818  0.046512
# 13  Worst professor I've ever had in my life. Exam...  0.247788  0.108108
# 14  Easiest grader ever.  The class is SO boring b...  0.265306  0.083333
# 15  Seidman is great. Nice guy. Really knows his s...  0.098361  0.033898
# 16  He is an *SS, He is cocky, arrogant, and leads...  0.252632  0.000000
# 17  Professor Hodge was the most confusing I have ...  0.256410  0.052174
# 18  Prof. Peterman is by far the worst professor I...  0.870370  0.867925
# 19  Very lecture heavy class. Several extra credit...  0.158416  0.000000
# 20  This man is the worst, most annoying, and uncl...  0.250000  0.069767
# 21  He was the worst professor I have ever had. I ...  0.327273  0.055556
# 22  Awesome guy, very personable. The class is eas...  0.283019  0.076923
# 23  She is fantastic, hands down.  You want to see...  0.242424  0.000000
# 24  The course had a lot of components to it. For ...  0.322581  0.021978
# 25  She is the worst, and she makes you not want t...  0.288889  0.068182
# 26  Prof. Beeson is extremely apathetic to student...  0.208000  0.000000
# 27  LOVED this teacher. He is older so he has stor...  0.907407  0.867925
# 28  Shes not a tough grader really. Criteria is pr...  0.277778  0.114286
# 29  Professor Nochera is super caring towards her ...  0.120690  0.017544
#
#       rougeL  rougeLsum
# 0   0.162162   0.162162
# 1   0.133333   0.133333
# 2   0.769231   0.769231
# 3   0.132231   0.132231
# 4   0.292135   0.292135
# 5   0.184874   0.184874
# 6   0.170940   0.170940
# 7   0.177778   0.177778
# 8   0.141732   0.141732
# 9   0.118812   0.118812
# 10  0.168421   0.168421
# 11  0.060606   0.060606
# 12  0.136364   0.136364
# 13  0.212389   0.212389
# 14  0.163265   0.163265
# 15  0.098361   0.098361
# 16  0.126316   0.126316
# 17  0.153846   0.153846
# 18  0.870370   0.870370
# 19  0.099010   0.099010
# 20  0.159091   0.159091
# 21  0.200000   0.200000
# 22  0.150943   0.150943
# 23  0.181818   0.181818
# 24  0.172043   0.172043
# 25  0.177778   0.177778
# 26  0.128000   0.128000
# 27  0.907407   0.907407
# 28  0.194444   0.194444
# 29  0.103448   0.103448

# %%
pred_df.to_csv("bart-summarizer-predictions.csv", encoding="utf-8")
